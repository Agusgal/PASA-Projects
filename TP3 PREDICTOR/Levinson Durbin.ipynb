# %%
import numpy as np
def do_levinson_durbin(r):
  r = np.array(r)
  M = len(r)
  w = np.zeros_like(r)
  K = np.zeros_like(r)
  wn = np.zeros_like(w)
  alpha = 0
  #init 
  w[0] = 1
  K[0] = -r[1]/r[0]
  alpha = r[0]*(1-np.power(K[0],2))
  print(alpha)
  for i in range(2,M):
    S = np.sum([r[j]*w[i-j] for j in range(1,i)]) + r[i]
    K[i] = (-S)/alpha
    for j in range(1,i):
      wn[j] = w[j]+K[i]*w[i-j]
    wn[i] = K[i]+1e-5
    print(wn[i])
    alpha = alpha*(1-np.power(K[i],2))
    print(alpha)
  return w

# %%
do_levinson_durbin([1,2,3,4,5])
# Out:
# -3
# 1
# 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in long_scalars
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-2-ea35fc27b5c6> in <module>()
# ----> 1 do_levinson_durbin([1,2,3,4,5])
#
# <ipython-input-1-3c80d4495074> in do_levinson_durbin(r)
#      14   for i in range(2,M):
#      15     S = np.sum([r[j]*w[i-j] for j in range(1,i)]) + r[i]
# ---> 16     K[i] = (-S)/alpha
#      17     for j in range(1,i):
#      18       wn[j] = w[j]+K[i]*w[i-j]
#
# OverflowError: cannot convert float infinity to integer
